# %%
class Zenith:
    def unique_services(self):
        pass
    
    def mutual_services(self):
        pass


class RetailBanking(Zenith):
    def unique_services(self):
        return [
            "Lines of credit",
            "Investment management and accounts",
            "Insurance",
            "Retirement and education accounts",
            "Loans and mortgages",
            "Checking and saving"
        ]
    
    def mutual_services(self):
        return [
            "Lines of credit",
            "Investment management and accounts",
            "Insurance"
        ]


class GlobalBanking(Zenith):
    def unique_services(self):
        return [
            "Multi-currency management services and products",
            "Foreign currency accounts",
            "Foreign currency credit cards",
            "Transborder advisory services",
            "Liquidity management"
        ]
    
    def mutual_services(self):
        return [
            "Investment management and accounts",
            "Insurance"
        ]


class CommercialBanking(Zenith):
    def unique_services(self):
        return [
            "Lines of credit",
            "Investment management and accounts",
            "Insurance",
            "Advisory services"
        ]
    
    def mutual_services(self):
        return [
            "Investment management and accounts",
            "Insurance"
        ]


def display_services(employee_name, division):
    if division == "Retail Banking":
        division_obj = RetailBanking()
    elif division == "Global Banking":
        division_obj = GlobalBanking()
    elif division == "Commercial Banking":
        division_obj = CommercialBanking()
    else:
        print("Invalid division")
        return
    
    print(f"Services rendered by {employee_name} in {division}:")
    print("Unique services:")
    unique_services = division_obj.unique_services()
    for service in unique_services:
        print("- " + service)
    
    print("\nMutual services:")
    mutual_services = division_obj.mutual_services()
    for service in mutual_services:
        print("- " + service)



employee_name = input("Enter name please: ")
division = input("Enter your division: ")
display_services(employee_name, division)
# Out:
# Enter name please: Noel
# Enter your division: Commercial Banking
# Services rendered by Noel in Commercial Banking:
# Unique services:
# - Lines of credit
# - Investment management and accounts
# - Insurance
# - Advisory services
#
# Mutual services:
# - Investment management and accounts
# - Insurance
